# %% [markdown]
# # [作業目標]
#
#
# 1. 請接下列資料依照指定規則做合併：
#
# ```
# - 依照 fruit 欄位做合併
# - 依照 index 索引做合併
# ```
#
# 2. [簡答題] 承上題，請問為什麼依照 merge 合併後有些資料不見了？
#
# 3. [簡答題] 承上題，請問為什麼依照 index 合併會發生錯誤？請用程式解決。

# %% [markdown]
# # 作業

# %%
# 記得先 Import 正確的套件

import pandas as pd
import numpy as np

# %% [markdown]
# ### 1. 請接下列資料依照指定規則做合併：
#
# ```
# - 依照 fruit 欄位做合併
# - 依照 index 索引做合併
# ```

# %%
df1 = pd.DataFrame({
    'fruit': ['apple', 'banana', 'orange'] * 3,
    'weight': ['high', 'medium', 'low'] * 3,
    'price': np.random.randint(0, 15, 9)
})

df2 = pd.DataFrame({
    'fruit': ['apple', 'orange', 'pine'] * 2,
    'weight': ['high', 'low'] * 3,
    'price': np.random.randint(0, 15, 6)
})
print(df1)
print(df2)
# Out:
#     fruit  weight  price
# 0   apple    high      4
# 1  banana  medium      9
# 2  orange     low      0
# 3   apple    high      5
# 4  banana  medium     11
# 5  orange     low      9
# 6   apple    high      8
# 7  banana  medium      2
# 8  orange     low     11
#     fruit weight  price
# 0   apple   high      3
# 1  orange    low      9
# 2    pine   high      0
# 3   apple    low     13
# 4  orange   high      9
# 5    pine    low      0

# %%
# - 依照 fruit 欄位做合併
pd.merge(df1, df2, on='fruit')
# Out:
#      fruit weight_x  price_x weight_y  price_y
# 0    apple     high        4     high        3
# 1    apple     high        4      low       13
# 2    apple     high        5     high        3
# 3    apple     high        5      low       13
# 4    apple     high        8     high        3
# 5    apple     high        8      low       13
# 6   orange      low        0      low        9
# 7   orange      low        0     high        9
# 8   orange      low        9      low        9
# 9   orange      low        9     high        9
# 10  orange      low       11      low        9
# 11  orange      low       11     high        9

# %%
pd.merge(df1, df2, how='outer')
# Out:
#      fruit  weight  price
# 0    apple    high      4
# 1   banana  medium      9
# 2   orange     low      0
# 3    apple    high      5
# 4   banana  medium     11
# 5   orange     low      9
# 6    apple    high      8
# 7   banana  medium      2
# 8   orange     low     11
# 9    apple    high      3
# 10    pine    high      0
# 11   apple     low     13
# 12  orange    high      9
# 13    pine     low      0

# %%
df1.join(df2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [14], line 1
# ----> 1 df1.join(df2)
#
# File ~/venv/lib/python3.9/site-packages/pandas/core/frame.py:9976, in DataFrame.join(self, other, on, how, lsuffix, rsuffix, sort, validate)
#    9813 def join(
#    9814     self,
#    9815     other: DataFrame | Series | list[DataFrame | Series],
#    (...)
#    9821     validate: str | None = None,
#    9822 ) -> DataFrame:
#    9823     """
#    9824     Join columns of another DataFrame.
#    9825
#    (...)
#    9974     5  K1  A5   B1
#    9975     """
# -> 9976     return self._join_compat(
#    9977         other,
#    9978         on=on,
#    9979         how=how,
#    9980         lsuffix=lsuffix,
#    9981         rsuffix=rsuffix,
#    9982         sort=sort,
#    9983         validate=validate,
#    9984     )
#
# ...

# %%
# - 依照 index 索引做合併
pd.concat([df1, df2]).reset_index(drop=True)
# Out:
#      fruit  weight  price
# 0    apple    high      4
# 1   banana  medium      9
# 2   orange     low      0
# 3    apple    high      5
# 4   banana  medium     11
# 5   orange     low      9
# 6    apple    high      8
# 7   banana  medium      2
# 8   orange     low     11
# 9    apple    high      3
# 10  orange     low      9
# 11    pine    high      0
# 12   apple     low     13
# 13  orange    high      9
# 14    pine     low      0

# %% [markdown]
# ### 2. [簡答題] 承上題，請問為什麼依照 merge 合併後有些資料不見了？

# %%
# pd.merge()的default是inner join,要兩邊都有才會合併(取交集)

# %% [markdown]
# ### 3. [簡答題] 承上題，請問為什麼依照 index 合併會發生錯誤？請用程式解決。

# %%
#兩個dataframe有些資料欄位重複，所以產生錯誤

# %%
df1.join(df2,lsuffix="_df1",rsuffix="_df2")
# Out:
#   fruit_df1 weight_df1  price_df1 fruit_df2 weight_df2  price_df2
# 0     apple       high          4     apple       high        3.0
# 1    banana     medium          9    orange        low        9.0
# 2    orange        low          0      pine       high        0.0
# 3     apple       high          5     apple        low       13.0
# 4    banana     medium         11    orange       high        9.0
# 5    orange        low          9      pine        low        0.0
# 6     apple       high          8       NaN        NaN        NaN
# 7    banana     medium          2       NaN        NaN        NaN
# 8    orange        low         11       NaN        NaN        NaN

# %%
pd.merge(df1,df2, left_index=True, right_index=True, how='outer')
# Out:
#   fruit_x weight_x  price_x fruit_y weight_y  price_y
# 0   apple     high        4   apple     high      3.0
# 1  banana   medium        9  orange      low      9.0
# 2  orange      low        0    pine     high      0.0
# 3   apple     high        5   apple      low     13.0
# 4  banana   medium       11  orange     high      9.0
# 5  orange      low        9    pine      low      0.0
# 6   apple     high        8     NaN      NaN      NaN
# 7  banana   medium        2     NaN      NaN      NaN
# 8  orange      low       11     NaN      NaN      NaN
